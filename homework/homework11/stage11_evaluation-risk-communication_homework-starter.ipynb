# %% [markdown]
# # Stage 11 Homework — Evaluation & Risk Communication
# In the lecture, we learned **parametric vs bootstrap CIs**, **scenario sensitivity**, and **subgroup checks**.
# Now, you will adapt those methods to your dataset and produce assumption-aware results.

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
np.random.seed(111)
plt.rcParams['figure.figsize'] = (8,5)

# %% [markdown]
# ## Load Data (provided or synthetic fallback)

# %%
from pathlib import Path
import pandas as pd
import numpy as np

data_dir = Path('data')
data_dir.mkdir(exist_ok=True)

csv_path = data_dir / 'data_stage11_eval_risk.csv'

if csv_path.exists():
    try:
        df = pd.read_csv(csv_path, parse_dates=['date'])
    except ValueError as e:
        print(f"Error reading CSV: {e}\nRegenerating synthetic data...")
        regenerate = True
    else:
        regenerate = False
else:
    regenerate = True

if regenerate:
    n = 180
    dates = pd.date_range('2022-06-01', periods=n, freq='D')
    seg = np.random.choice(['A','B','C'], size=n, p=[0.5,0.3,0.2])
    x = np.linspace(0, 9, n) + np.random.normal(0, 0.7, n)
    y = 2.1 * x + 0.8 + np.random.standard_t(df=3, size=n) * 1.1
    x[np.random.choice(np.arange(n), size=round(0.05*n), replace=False)] = np.nan
    df = pd.DataFrame({'date': dates, 'segment': seg, 'x_feature': x, 'y_target': y})
    df.to_csv(csv_path, index=False)

df.head()
# Out:
#         date segment  x_feature  y_target
# 0 2022-06-01       B   0.547868  2.107524
# 1 2022-06-02       A   0.974480  2.209111
# 2 2022-06-03       A  -0.012991  0.867315
# 3 2022-06-04       B  -1.012503 -1.741932
# 4 2022-06-05       A   0.642399  1.615007

# %% [markdown]
# ## Helper Functions (complete or modify as needed)

# %%
def mean_impute(a: np.ndarray) -> np.ndarray:
    m = np.nanmean(a)
    out = a.copy()
    out[np.isnan(out)] = m
    return out

def median_impute(a: np.ndarray) -> np.ndarray:
    m = np.nanmedian(a)
    out = a.copy()
    out[np.isnan(out)] = m
    return out

class SimpleLinReg:
    def fit(self, X, y):
        X1 = np.c_[np.ones(len(X)), X.ravel()]
        beta = np.linalg.pinv(X1) @ y
        self.intercept_, self.coef_ = float(beta[0]), np.array([float(beta[1])])
        return self
    def predict(self, X):
        return self.intercept_ + self.coef_[0] * X.ravel()

def mae(y_true, y_pred):
    return float(np.mean(np.abs(y_true - y_pred)))

def bootstrap_metric(y_true, y_pred, fn, n_boot=500, seed=111, alpha=0.05):
    rng = np.random.default_rng(seed)
    idx = np.arange(len(y_true))
    stats = []
    for _ in range(n_boot):
        b = rng.choice(idx, size=len(idx), replace=True)
        stats.append(fn(y_true[b], y_pred[b]))
    lo, hi = np.percentile(stats, [100*alpha/2, 100*(1-alpha/2)])
    return {'mean': float(np.mean(stats)), 'lo': float(lo), 'hi': float(hi)}

def fit_fn(X, y):
    return SimpleLinReg().fit(X, y)
def pred_fn(model, X):
    return model.predict(X)

# %% [markdown]
# ## Baseline Fit & Residuals (Required)

# %%
X_raw = df['x_feature'].values
y = df['y_target'].values
X_base = mean_impute(X_raw)
model = fit_fn(X_base.reshape(-1,1), y)
y_hat = model.predict(X_base.reshape(-1,1))
df['x_imputed'] = X_base
base_mae = mae(y, y_hat)
base_mae
# Out:
# 1.2783168286969486

# %% [markdown]
# ## Parametric vs Bootstrap CI (Required)

# %%
resid = y - y_hat
sigma_hat = np.std(resid, ddof=1)
n = len(y)
se_mean = sigma_hat/np.sqrt(n)
x_grid = np.linspace(np.nanmin(X_base), np.nanmax(X_base), 120).reshape(-1,1)
pred_line = model.predict(x_grid)
gauss_lo = pred_line - 1.96*se_mean
gauss_hi = pred_line + 1.96*se_mean

def bootstrap_predictions(X, y, x_grid, n_boot=500, seed=111):
    rng = np.random.default_rng(seed)
    preds = []
    idx = np.arange(len(y))
    for _ in range(n_boot):
        b = rng.choice(idx, size=len(idx), replace=True)
        m = fit_fn(X[b].reshape(-1,1), y[b])
        preds.append(m.predict(x_grid))
    P = np.vstack(preds)
    return P.mean(axis=0), np.percentile(P, 2.5, axis=0), np.percentile(P, 97.5, axis=0)

m_boot, lo_boot, hi_boot = bootstrap_predictions(X_base, y, x_grid, n_boot=600)

plt.figure()
plt.scatter(X_base, y, alpha=0.25)
plt.plot(x_grid, pred_line, label='prediction')
plt.fill_between(x_grid.ravel(), gauss_lo, gauss_hi, alpha=0.25, label='Gaussian CI')
plt.fill_between(x_grid.ravel(), lo_boot, hi_boot, alpha=0.25, label='Bootstrap CI')
plt.legend(); plt.title('Parametric vs Bootstrap CI'); plt.show()

# %%
# 1) Parametric CI width
width_param = 2 * 1.96 * se_mean
# 2) Bootstrap CI width
width_boot = hi_boot - lo_boot
stats = {
    "param_width": width_param,
    "boot_mean_width": np.mean(width_boot),
    "boot_min_width": np.min(width_boot),
    "boot_max_width": np.max(width_boot)
}
stats
# Out:
# {'param_width': 0.6099909361675778,
#  'boot_mean_width': 0.7908709931222954,
#  'boot_min_width': 0.591605500408459,
#  'boot_max_width': 1.1569538296727255}

# %% [markdown]
# From the figure and the statistics:
#
# The parametric CI width is about 0.61.
# The bootstrap CI width averages 0.79, with a range from 0.59 to 1.16 across resamples.
#
# This indicates that the parametric approach produces narrower, more “optimistic” intervals, while bootstrap intervals are generally wider and vary more, reflecting the data’s true variability. In other words, parametric CIs may underestimate uncertainty, while bootstrap CIs provide a more robust picture of risk.

# %% [markdown]
# ## Scenario Sensitivity (Required): Choose ≥2 Scenarios
# Examples: mean vs median impute; drop; alternate feature transform

# %%
missing_rate = df['x_feature'].isna().mean()
print(f"Missing rate in x_feature: {missing_rate:.2%}")
# Out:
# Missing rate in x_feature: 5.00%

# %%
scenarios = {
    'mean_impute': mean_impute,
    'median_impute': median_impute,
    'drop_missing': lambda a: a[~np.isnan(a)] if np.isnan(a).any() else a
}

results = []
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xs, ys = X_raw[mask], y[mask]
        m = fit_fn(Xs.reshape(-1,1), ys)
        yh = m.predict(Xs.reshape(-1,1))
    else:
        Xs = fn(X_raw)
        m = fit_fn(Xs.reshape(-1,1), y)
        yh = m.predict(Xs.reshape(-1,1))
    results.append({'scenario': name, 'mae': mae(y[:len(yh)], yh), 'slope': m.coef_[0], 'intercept': m.intercept_})
sens = pd.DataFrame(results); sens
# Out:
#         scenario       mae     slope  intercept
# 0    mean_impute  1.278317  2.130236   0.711523
# 1  median_impute  1.283954  2.129290   0.727146
# 2   drop_missing  2.061050  2.130236   0.659164

# %%
plt.figure()
xg = np.linspace(np.nanmin(X_base), np.nanmax(X_base), 150).reshape(-1,1)
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xi, yi = X_raw[mask], y[mask]
    else:
        Xi, yi = fn(X_raw), y
    m = fit_fn(Xi.reshape(-1,1), yi)
    plt.plot(xg, m.predict(xg), label=name)
plt.scatter(X_base, y, alpha=0.15)
plt.title('Scenario Fits (consistent axes)'); plt.legend(); plt.show()

# %% [markdown]
# Mean imputation and median imputation perform almost identically, both achieving an MAE of about 1.28, with nearly the same slope and intercept. This suggests the model is robust to the choice between mean vs. median imputation.
#
# Dropping missing values, however, degrades performance significantly: MAE rises to 2.06, indicating much higher prediction error.
#
# Conclusion: The model is sensitive to missing-data handling. Imputation (mean or median) maintains performance, while discarding missing rows should be avoided.

# %%
## Subgroup Diagnostic (Required)

# %%
model_base = fit_fn(X_base.reshape(-1,1), y)
df2 = df.copy()
df2['y_hat'] = model_base.predict(df2['x_imputed'].values.reshape(-1,1))
df2['resid'] = df2['y_target'] - df2['y_hat']
g = df2.groupby('segment')['resid'].agg(['mean','std','median','count'])
g
# Out:
#              mean       std    median  count
# segment
# A       -0.066306  1.827501 -0.235648     94
# B        0.294967  1.707514 -0.077390     41
# C       -0.130242  2.813215 -0.140354     45

# %%
plt.figure()
grouped = df2.groupby('segment')['resid']
data = [s.values for _, s in grouped]
labels = list(grouped.groups.keys())

plt.boxplot(data, labels=labels)
plt.title('Residuals by Segment')
plt.show()

# %% [markdown]
# Across segments A, B, and C, Segment B is the most reliable, Segment C is the riskiest, and Segment A is intermediate.
#
# Segment A shows relatively stable predictions, with a median residual of about -0.24 and mean around -0.07, indicating slight overprediction. The variability is moderate, and the large sample size (94) makes the results more reliable.
#
# Segment B has the smallest variability and a median residual close to zero, making it the most stable group. However, the mean residual is higher, suggesting a right-skewed distribution with a few large positive errors. With only 41 samples, the findings should be interpreted cautiously.
#
# Segment C shows both mean and median residuals below zero, implying consistent overprediction. It also has the largest variability, making this the riskiest group. Sample size is not large.

# %% [markdown]
# ## Bootstrap a Metric (Required)

# %%
bm = bootstrap_metric(y, df2['y_hat'].values, mae, n_boot=600)
bm
# Out:
# {'mean': 1.2714062440720522, 'lo': 1.0550822262814068, 'hi': 1.530997972363558}

# %% [markdown]
# ## Stakeholder Summary (Required — ≤ 1 page)
# - Key assumptions
# - Sensitivity results & takeaways
# - Subgroup risks
# - “Prediction holds if…”, “Model is sensitive to…”

# %% [markdown]
# ### Stakeholder Summary
#
# **Assumptions**
# - Data is representative; missing values are handled by mean/median imputation.
# - Feature–target relationship is assumed approximately linear.
# - Input patterns (e.g., volatility) remain within observed range.
#
# **Risks & Sensitivity**
# - **Uncertainty**: Parametric CIs are narrow, but bootstrap shows wider ranges → true error may be larger.
# - **Missing Data**: Performance stable with imputation; accuracy drops if rows are dropped. Sensitive if missing-rate >10%.
# - **Subgroups**: Segment B performs best (low, stable errors). Segment A moderate with some large outliers. Segment C underperforms with overprediction and high variability.
#
# **Takeaway**
# Prediction holds if data distribution remains similar to baseline
# Our dataset has a missing-value rate of 5%, and at this level, imputing missing entries with either the mean or the median does not affect the results.
# Model is reliable under current conditions and for Segment B， while isks rise with high missingness and in Segment C.
